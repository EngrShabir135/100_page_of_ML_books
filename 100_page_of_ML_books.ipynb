# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as sta

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# $$ f(x)=f^\prime(x) $$

# %% [markdown]
# $$ f(x)=x^2 $$
# $$ f^\prime(x)=? $$

# %% [markdown]
# $ \text{Solution:} f^\prime(x)=2x $

# %%
df=pd.read_csv("Clean_data_mobile.csv",index_col='Unnamed: 0')

# %%
df.head()
# Out:
#    Price                Name  Ram    Rom   Display      Battery    Rating  \
# 0  31950  Samsung Galaxy A14  4.0  128.0  6.600000  4997.714286  3.300000
# 1  32099         Samsung A14  4.0  128.0  6.659227  5000.000000  4.500000
# 2  21950            Itel S23  8.0  256.0  6.600000  4997.714286  4.600000
# 3  30499         Galaxy A04s  4.0  128.0  6.659227  4997.714286  4.300000
# 4  19998        Neo 7 Plus |  4.0   64.0  6.560000  5000.000000  4.433242
#
#     Sold
# 0   51.0
# 1  240.0
# 2  478.0
# 3  227.0
# 4   60.0

# %%
import scipy.stats as sta

# %%
fig,axis=plt.subplots(1,2,figsize=(15,4))

sns.distplot(df["Price"],ax=axis[0])
axis[0].set_title("Distplot of price")

sta.probplot(df['Price'], dist="norm", plot=axis[1])
axis[1].set_title('QQ Plot', fontsize=16)
# Out:
# Text(0.5, 1.0, 'QQ Plot')

# %%
df=sns.load_dataset("tips")

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
fig,axis=plt.subplots(1,3,figsize=(15,6))

sns.lineplot(df['total_bill'],ax=axis[0])
axis[0].set_title("line plot of total_bill")

sns.distplot(df['total_bill'],ax=axis[1])
axis[1].set_title("distplot of total_bill")

sta.probplot(df['total_bill'],dist='norm',plot=axis[2])
axis[2].set_title("Probplot of total_bill")

plt.show()

# %%
a=0b1001

# %%
type(a)
# Out:
# int

# %%
0o243
# Out:
# 163

# %%
color_list = ["Red","Green","White" ,"Black"]
print(color_list[0])
print(color_list[-1])
# Out:
# Red
# Black

# %%
print("%s %s" % (color_list[0], color_list[-1]))
# Out:
# Red Black

# %%
# Generate some sample data
x = np.linspace(0, 10, 100)
y1 = np.sin(x)
y2 = np.cos(x)
y3 = np.tan(x)

# Create subplots with 1 row and 3 columns
fig, axs = plt.subplots(1, 3, figsize=(15, 5))

# Plot data on each subplot
axs[0].plot(x, y1, color='blue')
axs[0].set_title('Sine Function')

axs[1].plot(x, y2, color='red')
axs[1].set_title('Cosine Function')

axs[2].plot(x, y3, color='green')
axs[2].set_title('Tangent Function')

# Adjust layout
plt.tight_layout()

# Show the plot
plt.show()

# %%
x=np.linspace(0,10,100)

# %%
y=np.sin(x)

# %%
y1=np.cos(x)
y2=np.tan(x)

# %%
fig,axis=plt.subplots(1,3,figsize=(15,4))

axis[0].plot(x,y,color='green')
axis[0].set_title("Sinx")

axis[1].plot(x,y1,color='red')
axis[1].set_title("Cosx")

axis[2].plot(x,y2,color='blue')
axis[2].set_title("Tanx")

plt.show()

# %%
exam_st_date = (11, 12, 2014)
print("The examination will be start {} / {} / {}".format(exam_st_date[0],exam_st_date[1],exam_st_date[2]))
# Out:
# The examination will be start 11 / 12 / 2014

# %%
a=int(input("Enter your number "))
n1=int("%s"%a)
n2=int("%s%s"%(a,a))
n3=int("%s%s%s"%(a,a,a))
print(n1)
print(n2)
print(n3)
print(n1+n2+n3)
# Out:
# Enter your number 5
# 5
# 55
# 555
# 615

# %%
def func(data):
    if len(data)==len(set(data)):
        return True
    else:
        return False

# %%
print(func([1,2,3,4,5]))
# Out:
# True

# %%
import random

# %%
char_list=['a','e','i','o','u']
random.shuffle(char_list)
print(''.join(char_list))
# Out:
# euaio

# %%
df.head()
# Out:
#    Price                Name  Ram    Rom   Display      Battery    Rating  \
# 0  31950  Samsung Galaxy A14  4.0  128.0  6.600000  4997.714286  3.300000
# 1  32099         Samsung A14  4.0  128.0  6.659227  5000.000000  4.500000
# 2  21950            Itel S23  8.0  256.0  6.600000  4997.714286  4.600000
# 3  30499         Galaxy A04s  4.0  128.0  6.659227  4997.714286  4.300000
# 4  19998        Neo 7 Plus |  4.0   64.0  6.560000  5000.000000  4.433242
#
#     Sold
# 0   51.0
# 1  240.0
# 2  478.0
# 3  227.0
# 4   60.0

# %%
fig=plt.figure(figsize=(15,8))
plt.subplot(1,2,1)
sns.distplot(df['Sold'])

plt.subplot(1,2,2)
sns.boxenplot(df['Sold'])

plt.show()

# %%
fig=plt.figure(figsize=(10,5))
plt.subplot(1,2,1)
sns.distplot(df['Price'])

plt.subplot(1,2,2)
sns.boxenplot(df['Price'])

plt.show()
